# %% [markdown]
# # **Experiment - 5 DHV**

# %% [markdown]
# **1) Clustering**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

data, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, random_state=42).fit(data)

plt.scatter(data[:, 0], data[:, 1], c=kmeans.labels_, cmap='viridis', label='Clusters')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title('Clustering')
plt.legend()
plt.show()

# %% [markdown]
# **2) Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt

stock_returns = np.random.normal(0.001, 0.02, 1000)
plt.hist(stock_returns, bins=30, color='blue', alpha=0.7)
plt.title('Stock Returns Histogram')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **3) Heatmap**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(42)
data = pd.DataFrame({
    'Revenue': np.random.normal(100, 20, 100),
    'Expenses': np.random.normal(70, 15, 100),
    'Profit': np.random.normal(30, 10, 100),
    'Debt': np.random.normal(50, 15, 100)
})

sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Financial Metrics Correlation Heatmap')
plt.show()
